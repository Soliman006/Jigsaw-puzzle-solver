# %% [markdown]
# # Puzzle Solver

# %% [markdown]
# Example Execution of the puzzle solver.

# %%
#%load_ext autotime

# %%
# !git clone -l -s https://USERNAME:PASSWORD@github.com/BenSoltau/jigsaw-puzzle-solver.git cloned-repo
# pull updates from GitHub
#!git pull
# activate the ben-dev branch
#!git checkout ben-dev

# %%
# %cd C:\Users\Ben\Documents\Python\puzzle-solver3
# Out:
# C:\Users\Ben\Documents\Python\puzzle-solver3

# %%
import cv2

# %%
from global_settings import globalSettings

# %%
settings = globalSettings()

settings.env = 'JUPYTER'  # 'JUPYTER' or 'DEFAULT'

settings.show_extraction_headings = True
settings.show_extraction_text = False
settings.show_basic_extraction_graphics = True
settings.show_full_extraction_graphics = True
settings.show_extracted_colours = False
settings.show_colour_extraction_progress = False

settings.show_incremental_solution = True
settings.show_colour_comparison = False
settings.show_comparison_text = False
settings.show_selection_text = False
settings.show_current_space_text = False
settings.show_solver_progress_text = False
settings.show_error_text = True
settings.show_backtracker = False

settings.helper = False

settings.score_mult_colour = 5

settings.select_border = 0

# %%
from extraction.extractor import ExtractedData
from extraction.contour_finder import approxContours
from solving.solver import Solver
from extraction.image_import import retrieveExample
from graphics import createSpacedSolution, displaySpacedSolution, createSolution, displaySolution, createBGRSolution, displayBGRSolution
from graphics import createGIFSequential, createGIFTransformation
from utils import hsv_to_cvhsv

# %%
# dataset 1
settings.e_contour_smoothing = 0.5
settings.score_thresh = 1.72 # if no options are under this then it trigger the backtracker
settings.helper_threshold = 1.5 # all options within this multiplier are considered
settings.max_options = 3

# dataset 2
#settings.lower_blue = hsv_to_cvhsv(0, 0, 0)
#settings.upper_blue = hsv_to_cvhsv(360, 1, 1)
#settings.e_contour_smoothing = 0.5
#settings.score_thresh = 1.72 # if no options are under this then it trigger the backtracker
#settings.helper_threshold = 1.5 # all options within this multiplier are considered
#settings.max_options = 3

# dataset 3
#settings.lower_blue = hsv_to_cvhsv(0, 0, 85)
#settings.upper_blue = hsv_to_cvhsv(360, 100, 100)
#settings.compute_height = 993
#settings.e_contour_smoothing = 0.5
#settings.score_thresh = 1.72 # if no options are under this then it trigger the backtracker
#settings.helper_threshold = 1.5 # all options within this multiplier are considered
#settings.max_options = 3

# %% [markdown]
# # Data Importing

# %%
img_orig = retrieveExample('1_unsolved.jpg')
img_target = retrieveExample('1_target.jpg')
#img_orig = cv2.imread('/PATH/TO/CUSTOM/IMAGE.jpg', cv2.IMREAD_UNCHANGED)
#img_target = cv2.imread('/content/drive/My Drive/Colab Notebooks/Capstone/V2/cloned-repo/datasets/solved/target1.jpg', cv2.IMREAD_UNCHANGED)

# %% [markdown]
# # Puzzle Maker

# %%
#from maker.maker import PuzzleMaker
#n_rows = 6
#img_maker_input = retrieveExample('1_target.jpg')
#gen_puzzle = PuzzleMaker(img_maker_input, n_rows, settings)
#gen_puzzle.overlay()
#gen_puzzle.display_result()

# %% [markdown]
# # Extraction

# %%
data = ExtractedData(img_orig, settings)

# %%
data.extract()
# Out:
# importing image
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4CB538760>
# finding contours
# <PIL.Image.Image image mode=L size=533x400 at 0x1C4CB844B80>
# Number of Puzzle Pieces: 54
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4CB8388E0>
# detecting clearance radii
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4CB8388E0>
# creating hulls
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4CB844BB0>
# finding corners
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4CB838610>
# detecting convexity defects
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4CB8755B0>
# finding piece centers
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4CB844BB0>
# splitting piece contours into sides
# determining piece types
# C:\Users\Ben\anaconda3\envs\capstone\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4C9D60BE0>
# detecting locks
# <PIL.Image.Image image mode=RGB size=533x400 at 0x1C4C9D60BE0>
# aligning pieces
# Divide by 0 encountered at piece 36 side 2 Don't worry it has been handled
# piece 36 has dual flags
# Divide by 0 encountered at piece 42 side 0 Don't worry it has been handled
# piece 42 has dual flags
# piece 46 has dual flags
# <PIL.Image.Image image mode=RGB size=571x400 at 0x1C4C9D6A9D0>
# preparing data
# <PIL.Image.Image image mode=RGB size=571x400 at 0x1C4CB844B80>
# performing BGR data manipulation
# <PIL.Image.Image image mode=RGB size=571x400 at 0x1C4C9D6A9D0>
# identifying piece edge colours
# EXTRACTION COMPLETE

# %%
data.processed_pieces = approxContours(data.processed_pieces, settings.e_contour_smoothing, state=False)

# %%
#data.visualPiecesInspection()

# %% [markdown]
# # Solver

# %%
puzzle = Solver(data, settings)

# %%
# format: manualCompare(piece1,side1,rotation1,piece2,side2,rotation2)
#puzzle.manualCompare(15,2,1,13,2,3)
#puzzle.manualCompare(15,2,1,12,3,0)
#puzzle.manualCompare(15,2,1,10,3,0)

# %%
puzzle.hardReset()

# %%
# format: manualPlace([x,y],piece,rotation)
'''
# top row: left to right
puzzle.manualPlace([0,0],0,0)
puzzle.manualPlace([1,0],15,0)
puzzle.manualPlace([2,0],13,0)
puzzle.manualPlace([3,0],16,0)
puzzle.manualPlace([4,0],12,0)
puzzle.manualPlace([5,0],20,0)
puzzle.manualPlace([6,0],10,0)
puzzle.manualPlace([7,0],4,0)
puzzle.manualPlace([8,0],1,1)
# right side: top to bottom
puzzle.manualPlace([8,1],25,1)
puzzle.manualPlace([8,2],23,1)
puzzle.manualPlace([8,3],19,1)
puzzle.manualPlace([8,4],6,1)
puzzle.manualPlace([8,5],2,2)

# left side: top to bottom
puzzle.manualPlace([0,1],9,3)
puzzle.manualPlace([0,2],8,3)
puzzle.manualPlace([0,3],21,3)
puzzle.manualPlace([0,4],18,3)
puzzle.manualPlace([0,5],3,3)

# bottom row: left to right
puzzle.manualPlace([1,5],5,2)
puzzle.manualPlace([2,5],7,2)
puzzle.manualPlace([3,5],14,2)
puzzle.manualPlace([4,5],22,2)
puzzle.manualPlace([5,5],17,2)
puzzle.manualPlace([6,5],24,2)
puzzle.manualPlace([7,5],11,2)
'''
# Out:
# '\n# top row: left to right\npuzzle.manualPlace([0,0],0,0)\npuzzle.manualPlace([1,0],15,0)\npuzzle.manualPlace([2,0],13,0)\npuzzle.manualPlace([3,0],16,0)\npuzzle.manualPlace([4,0],12,0)\npuzzle.manualPlace([5,0],20,0)\npuzzle.manualPlace([6,0],10,0)\npuzzle.manualPlace([7,0],4,0)\npuzzle.manualPlace([8,0],1,1)\n# right side: top to bottom\npuzzle.manualPlace([8,1],25,1)\npuzzle.manualPlace([8,2],23,1)\npuzzle.manualPlace([8,3],19,1)\npuzzle.manualPlace([8,4],6,1)\npuzzle.manualPlace([8,5],2,2)\n\n# left side: top to bottom\npuzzle.manualPlace([0,1],9,3)\npuzzle.manualPlace([0,2],8,3)\npuzzle.manualPlace([0,3],21,3)\npuzzle.manualPlace([0,4],18,3)\npuzzle.manualPlace([0,5],3,3)\n\n# bottom row: left to right\npuzzle.manualPlace([1,5],5,2)\npuzzle.manualPlace([2,5],7,2)\npuzzle.manualPlace([3,5],14,2)\npuzzle.manualPlace([4,5],22,2)\npuzzle.manualPlace([5,5],17,2)\npuzzle.manualPlace([6,5],24,2)\npuzzle.manualPlace([7,5],11,2)\n'

# %%
puzzle.solve()
# Out:
# solveJourney
# solveLeg
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB8388E0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB538F70>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB8692E0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB8697C0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB8697C0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB8697C0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB869B50>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB8696A0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB869D60>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4CB869A60>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6431430>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6431FD0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6431430>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64314F0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D642AFA0>
# path length 4
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4C9D7AFA0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6431FD0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6430520>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64304F0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D642AA90>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D642AAF0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D642A9A0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D642A8E0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6430640>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6430FD0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64306D0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D644C760>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D644C8E0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D644C8B0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D644C760>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D644CB20>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6428340>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64284F0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64501F0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6450520>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6450520>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64502E0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6450FA0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6450310>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64501F0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6450550>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6450550>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6450550>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6451BB0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6451400>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6451AF0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6451C40>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6451400>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64536A0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6453790>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6459070>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6459430>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D64592E0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6459130>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6459490>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A670>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A670>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A820>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A880>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A6D0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A670>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A970>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645CEB0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A5B0>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A880>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D645A970>
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6375EE0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6375EE0>
# path length 6
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6375D90>
# path length 6
# Number of paths before ranking 29
# final_step -1 leg_start 0
# <PIL.Image.Image image mode=RGB size=285x200 at 0x1C4D6378FA0>
# solveLeg
# path length 6
# Number of paths before ranking 0
# final_step 3 leg_start 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-2ba440f73f1e> in <module>
# ----> 1 puzzle.solve()
#
# ~\Documents\Python\puzzle-solver3\solving\solver.py in solve(self)
#      81     def solve(self):
#      82         """Main function for initiating the iterative solving process with backtracking."""
# ---> 83         self.journey = self.solveJourney()
#      84         if len(self.memory) == self.n_pieces:
#      85             print("Puzzle Solved")
#
# ~\Documents\Python\puzzle-solver3\solving\solver.py in solveJourney(self)
#      94             leg_start = self.leg_points[i_leg]
#      95             leg_end = self.leg_points[i_leg + 1]
# ---> 96             leg = self.solveLeg(leg_start, leg_end)
#      97             self.legs.append(leg)
#      98             final_step = len(leg)-1
#
# ~\Documents\Python\puzzle-solver3\solving\solver.py in solveLeg(self, leg_start, leg_end)
#     114                 print("final_step", final_step, "leg_start", leg_start)
#     115                 ranked_paths = rankPaths(self.paths, self.settings)
# --> 116                 leg = ranked_paths[0][1]
#     117                 self.flags.backtrack = False
#     118                 return leg
#
# IndexError: list index out of range

# %%
puzzle.paths
# Out:
# []

# %%
puzzle.legs
# Out:
# [[<solving.utils.Step at 0x1dfffcd5190>,
#   <solving.utils.Step at 0x1dfff9e6700>,
#   <solving.utils.Step at 0x1dfffcd5730>,
#   <solving.utils.Step at 0x1dfffcd5580>,
#   <solving.utils.Step at 0x1dfffcd5610>,
#   <solving.utils.Step at 0x1dfffcd5940>]]

# %%
for step in range(len(puzzle.memory)):
    print("space", puzzle.memory[step].space, "choice", puzzle.memory[step].choice)
    for option in range(len(puzzle.memory[step].options)):
        print("piece", puzzle.memory[step].options[option].piece, "rotation", puzzle.memory[step].options[option].rotation, "score", puzzle.memory[step].options[option].score)
# Out:
# space [0, 0] choice 0
# piece 0 rotation 0 score 0
# space [1, 0] choice 0
# piece 15 rotation 0 score 1.0912941780381775
# piece 20 rotation 0 score 1.1618233113455934
# piece 16 rotation 0 score 1.2343143702912813
# space [2, 0] choice 0
# piece 12 rotation 0 score 0.8552735718129825
# piece 10 rotation 0 score 0.9681695168700716
# piece 13 rotation 0 score 1.2201102188976278
# space [3, 0] choice 0
# piece 20 rotation 0 score 0.6313204832915706
# piece 16 rotation 0 score 0.7082768995321171
# space [4, 0] choice 0
# piece 10 rotation 0 score 0.8579163648821433
# space [5, 0] choice 0
# piece 4 rotation 0 score 0.8941709558386667

# %% [markdown]
# # Solution Display

# %%
displaySpacedSolution(createSpacedSolution(data, puzzle), data.radius_max, puzzle.x_limit, puzzle.y_limit, settings)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x21AA474CB50>
# time: 26 ms

# %%
displaySolution(createSolution(data, puzzle), data.av_length, puzzle.x_limit, puzzle.y_limit, settings)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-23-b4f471c1d02d> in <module>
# ----> 1 displaySolution(createSolution(data, puzzle), data.av_length, puzzle.x_limit, puzzle.y_limit, settings)
#
# ~\Documents\Python\puzzle-solver2\graphics.py in createSolution(data, puzzle)
#      85                     angle = -angle - 90  # even weirder shit
#      86                 solution_contour = rotate_contour(solution_contour, puzzle.centers_solution[piece], angle)
# ---> 87             solution_contours.append(solution_contour)
#      88     return solution_contours
#      89
#
# UnboundLocalError: local variable 'solution_contour' referenced before assignment

# %%
puzzle.solution_bgr, solution_contours = createBGRSolution(data, puzzle)
displayBGRSolution(puzzle.solution_bgr, data.av_length, puzzle.x_limit, puzzle.y_limit, settings)
# Out:
# <PIL.Image.Image image mode=RGB size=571x400 at 0x268E9722E20>

# %% [markdown]
# # GIF

# %%
createGIFSequential(data,puzzle)
# GIF is located in the root directory of the repository

# %%
createGIFTransformation(data,puzzle)
